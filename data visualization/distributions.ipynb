# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Path of the file to read

cancer_b = "C:/Users/HP/Desktop/Kaggle Assignment/Data Visualization/Distributions/cancer_b.csv"
cancer_m = "C:/Users/HP/Desktop/Kaggle Assignment/Data Visualization/Distributions/cancer_m.csv"


# Read the file 
cancer_b_data = pd.read_csv(cancer_b, index_col="Id")
cancer_m_data = pd.read_csv(cancer_m, index_col="Id")

# %%
# Print the first 5 rows of the data
print("Belign Data")
cancer_b_data.head()
# Out:
# Belign Data
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
print("Melignant Data")
cancer_m_data.head()
# Out:
# Melignant Data
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 842302           M          17.99           10.38            122.80
# 842517           M          20.57           17.77            132.90
# 84300903         M          19.69           21.25            130.00
# 84348301         M          11.42           20.38             77.58
# 84358402         M          20.29           14.34            135.10
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 842302         1001.0            0.11840             0.27760
# 842517         1326.0            0.08474             0.07864
# 84300903       1203.0            0.10960             0.15990
# 84348301        386.1            0.14250             0.28390
# 84358402       1297.0            0.10030             0.13280
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
#In the first five rows of the data for benign tumors, what is the largest value for 'Perimeter (mean)'?
c=cancer_b_data.head()
max_perim = c['Perimeter (mean)'].max()
max_perim

# What is the value for 'Radius (mean)' for the tumor with Id 842517?
#mean_radius = cancer_b_data[cancer_b_data["Id"]== "842517"]
#mean_radius
# Out:
# 87.46

# %%
# Histogram 
sns.distplot(a=cancer_b_data['Area (mean)'], label="benign", kde=False)
sns.distplot(a=cancer_m_data['Area (mean)'], label="melignant", kde=False)
plt.legend()
# Out:
# E:\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# KDE plot 
sns.kdeplot(data=cancer_b_data['Radius (worst)'], label="benign", shade=True)
sns.kdeplot(data=cancer_m_data['Radius (worst)'], label="melignant", shade=True)
plt.legend()
